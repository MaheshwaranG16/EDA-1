# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df=pd.read_csv("netflix_titles.csv")
df
# Out:
#      show_id     type                  title         director  \
# 0         s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1         s2  TV Show          Blood & Water              NaN
# 2         s3  TV Show              Ganglands  Julien Leclercq
# 3         s4  TV Show  Jailbirds New Orleans              NaN
# 4         s5  TV Show           Kota Factory              NaN
# ...      ...      ...                    ...              ...
# 8802   s8803    Movie                 Zodiac    David Fincher
# 8803   s8804  TV Show            Zombie Dumb              NaN
# 8804   s8805    Movie             Zombieland  Ruben Fleischer
# 8805   s8806    Movie                   Zoom     Peter Hewitt
# 8806   s8807    Movie                 Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 0                                                   NaN  United States
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# ...

# %%
df.describe()
# Out:
#        release_year
# count   8807.000000
# mean    2014.180198
# std        8.819312
# min     1925.000000
# 25%     2013.000000
# 50%     2017.000000
# 75%     2019.000000
# max     2021.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8807 entries, 0 to 8806
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       8807 non-null   object
#  1   type          8807 non-null   object
#  2   title         8807 non-null   object
#  3   director      6173 non-null   object
#  4   cast          7982 non-null   object
#  5   country       7976 non-null   object
#  6   date_added    8797 non-null   object
#  7   release_year  8807 non-null   int64
#  8   rating        8803 non-null   object
#  9   duration      8804 non-null   object
#  10  listed_in     8807 non-null   object
#  11  description   8807 non-null   object
# dtypes: int64(1), object(11)
# memory usage: 825.8+ KB

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df = df.drop_duplicates()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 8807 entries, 0 to 8806
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       8807 non-null   object
#  1   type          8807 non-null   object
#  2   title         8807 non-null   object
#  3   director      6173 non-null   object
#  4   cast          7982 non-null   object
#  5   country       7976 non-null   object
#  6   date_added    8797 non-null   object
#  7   release_year  8807 non-null   int64
#  8   rating        8803 non-null   object
#  9   duration      8804 non-null   object
#  10  listed_in     8807 non-null   object
#  11  description   8807 non-null   object
# dtypes: int64(1), object(11)
# memory usage: 894.5+ KB

# %%
plt.figure(figsize=(10, 6))
sns.heatmap(df.isnull(), cmap='Set3', cbar=False, yticklabels=False)
plt.title('Null Values Heatmap')
plt.show()

# %%
house_of_cards = df[df['title'] == 'House of Cards']

if not house_of_cards.empty:
    show_id = house_of_cards['show_id'].values[0]
    director = house_of_cards['director'].values[0]
    print("Show ID:", show_id)
    print("Director:", director)
else:
    print("Show 'House of Cards' not found.")
# Out:
# Show ID: s1060
# Director: nan

# %%
house_of_cards
# Out:
#      show_id     type           title director  \
# 1059   s1060  TV Show  House of Cards      NaN
#
#                                                    cast        country  \
# 1059  Kevin Spacey, Robin Wright, Kate Mara, Corey S...  United States
#
#           date_added  release_year rating   duration                listed_in  \
# 1059  April 14, 2021          2018  TV-MA  6 Seasons  TV Dramas, TV Thrillers
#
#                                             description  duration_minutes
# 1059  A ruthless politician will stop at nothing to ...            7200.0

# %%
release_counts = df.groupby('release_year')['type'].count()
release_counts
# Out:
# release_year
# 1925       1
# 1942       2
# 1943       3
# 1944       3
# 1945       4
#         ...
# 2017    1032
# 2018    1147
# 2019    1030
# 2020     953
# 2021     592
# Name: type, Length: 74, dtype: int64

# %%
max_year = release_counts.idxmax()
max_releases = release_counts.max()

# %%
plt.figure(figsize=(20, 6))
release_counts.plot(kind='bar', color='skyblue')
plt.title('Number of TV Shows and Movies Released Each Year')
plt.xlabel('Release Year')
plt.ylabel('Number of Releases')
plt.xticks(rotation=45)
plt.axvline(x=max_year, color='red', linestyle='--', linewidth=2, label=f'Highest: {max_year} ({max_releases} releases)')
plt.legend()
plt.tight_layout()
plt.show()

# %%
type_counts = df['type'].value_counts()
type_counts
# Out:
# Movie      6131
# TV Show    2676
# Name: type, dtype: int64

# %%
plt.figure(figsize=(8, 6))
type_counts.plot(kind='bar', color=['skyblue', 'lightgreen'])
plt.title('Number of Movies and TV Shows in the Dataset')
plt.xlabel('Type')
plt.ylabel('Count')
plt.xticks(rotation=0)
plt.tight_layout()
plt.show()

# %%
movies_2000 = df[(df['type'] == 'Movie') & (df['release_year'] == 2000)]
movies_2000
# Out:
#      show_id   type                                              title  \
# 180     s181  Movie                 The Nutty Professor II: The Klumps
# 350     s351  Movie                                      Space Cowboys
# 359     s360  Movie                       The Original Kings of Comedy
# 566     s567  Movie                                   Charlie's Angels
# 593     s594  Movie                                           Snow Day
# 779     s780  Movie                                  Battlefield Earth
# 952     s953  Movie                               The Whole Nine Yards
# 3472   s3473  Movie                        Rugrats in Paris: The Movie
# 4545   s4546  Movie             Monty Python: Before the Flying Circus
# 4723   s4724  Movie                                               Fiza
# 4956   s4957  Movie                        Phir Bhi Dil Hai Hindustani
# 5953   s5954  Movie                             Joseph: King of Dreams
# ...

# %%
tv_shows_india = df[(df['type'] == 'TV Show') & (df['country'] == 'India')]
tv_shows_india['title']
# Out:
# 4                             Kota Factory
# 39                            Chhota Bheem
# 50                           Dharmakshetra
# 66           Raja Rasoi Aur Anya Kahaniyan
# 69          Stories by Rabindranath Tagore
#                        ...
# 8173                             Thackeray
# 8235                           The Calling
# 8321    The Golden Years with Javed Akhtar
# 8349                The House That Made Me
# 8775                       Yeh Meri Family
# Name: title, Length: 79, dtype: object

# %%
# Group by director and count the number of TV shows and movies
director_counts = df['director'].value_counts()

# Get top 10 directors
top_10_directors = director_counts.head(10)
top_10_directors
# Out:
# Rajiv Chilaka             19
# Raúl Campos, Jan Suter    18
# Marcus Raboy              16
# Suhas Kadav               16
# Jay Karas                 14
# Cathy Garcia-Molina       13
# Martin Scorsese           12
# Youssef Chahine           12
# Jay Chapman               12
# Steven Spielberg          11
# Name: director, dtype: int64

# %%
df[(df.type =='Movie') &(df.listed_in =='Comedies')|(df.country == 'United Kingdom')]
# Out:
#      show_id     type                                   title  \
# 8         s9  TV Show           The Great British Baking Show
# 27       s28    Movie                               Grown Ups
# 32       s33  TV Show                           Sex Education
# 65       s66  TV Show                            Numberblocks
# 72       s73  TV Show  Jack Whitehall: Travels with My Father
# ...      ...      ...                                     ...
# 8740   s8741  TV Show                             Wild Alaska
# 8741   s8742  TV Show                             Wild Arabia
# 8744   s8745    Movie                                Williams
# 8758   s8759  TV Show                  World's Busiest Cities
# 8786   s8787    Movie                            You Can Tutu
#
#              director                                               cast  \
# 8     Andy Devonshire  Mel Giedroyc, Sue Perkins, Mary Berry, Paul Ho...
# ...

# %%
filtered_records = df[((df['type'] == 'Movie') & (df['listed_in'].str.contains('Comedies'))) | (df['country'] == 'United Kingdom')]
filtered_records
# Out:
#      show_id     type                                   title  \
# 8         s9  TV Show           The Great British Baking Show
# 27       s28    Movie                               Grown Ups
# 32       s33  TV Show                           Sex Education
# 65       s66  TV Show                            Numberblocks
# 72       s73  TV Show  Jack Whitehall: Travels with My Father
# ...      ...      ...                                     ...
# 8740   s8741  TV Show                             Wild Alaska
# 8741   s8742  TV Show                             Wild Arabia
# 8744   s8745    Movie                                Williams
# 8758   s8759  TV Show                  World's Busiest Cities
# 8786   s8787    Movie                            You Can Tutu
#
#              director                                               cast  \
# 8     Andy Devonshire  Mel Giedroyc, Sue Perkins, Mary Berry, Paul Ho...
# ...

# %%
tom_cruise_count = df[df['cast'].str.contains('Tom Cruise', na=False)].shape[0]

print(f"The number of movies/shows where Tom Cruise was cast: {tom_cruise_count}")
# Out:
# The number of movies/shows where Tom Cruise was cast: 2

# %%
rating=df['rating'].unique()
rating
# Out:
# array(['PG-13', 'TV-MA', 'PG', 'TV-14', 'TV-PG', 'TV-Y', 'TV-Y7', 'R',
#        'TV-G', 'G', 'NC-17', '74 min', '84 min', '66 min', 'NR', nan,
#        'TV-Y7-FV', 'UR'], dtype=object)

# %%
for rating in rating:
    print(rating)
# Out:
# PG-13
# TV-MA
# PG
# TV-14
# TV-PG
# TV-Y
# TV-Y7
# R
# TV-G
# G
# NC-17
# 74 min
# 84 min
# 66 min
# NR
# nan
# TV-Y7-FV
# UR

# %%
tv_14_movies_canada_count = df[(df['type'] == 'Movie') & (df['rating'] == 'TV-14') & (df['country'] == 'Canada')].shape[0]

print(f"The number of movies with 'TV-14' rating from Canada: {tv_14_movies_canada_count}")
# Out:
# The number of movies with 'TV-14' rating from Canada: 13

# %%
r_rating_tv_shows_count = df[(df['type'] == 'TV Show') & (df['rating'] == 'TV-MA') & (df['release_year'] > 2018)].shape[0]
print(f"The number of TV shows with 'R' rating after year 2018: {r_rating_tv_shows_count}")
# Out:
# The number of TV shows with 'R' rating after year 2018: 623

# %%
df['duration_minutes'] = df['duration'].str.extract('(\d+)', expand=False).astype(float)
# Multiply the duration by 60 for TV Shows
df.loc[df['type'] == 'TV Show', 'duration_minutes'] *= 20 * 60  # Assuming 1 season is approximately 20 episodes and each episode is 60 minutes

# Find the maximum duration
max_duration = df['duration_minutes'].max()

print(f"The maximum duration of a movie/show on Netflix is: {max_duration} minutes")
# Out:
# The maximum duration of a movie/show on Netflix is: 20400.0 minutes

# %%
tv_shows_df = df[df['type'] == 'TV Show']

# Count the occurrences of each country
country_counts = tv_shows_df['country'].value_counts()

# Get the country with the highest number of TV shows
country_with_highest_tv_shows = country_counts.idxmax()
highest_tv_show_count = country_counts.max()

print(f"The country with the highest number of TV shows is {country_with_highest_tv_shows} with {highest_tv_show_count} TV shows.")
# Out:
# The country with the highest number of TV shows is United States with 760 TV shows.

# %%
sorted_df = df.sort_values(by='release_year')
sorted_df
# Out:
# Sorted Dataset by Year:
#      show_id     type                                          title  \
# 4250   s4251  TV Show              Pioneers: First Women Filmmakers*
# 7790   s7791    Movie                                 Prelude to War
# 8205   s8206    Movie                           The Battle of Midway
# 8660   s8661    Movie  Undercover: How to Operate Behind Enemy Lines
# 8739   s8740    Movie             Why We Fight: The Battle of Russia
# ...      ...      ...                                            ...
# 862     s863  TV Show                                        Special
# 861     s862    Movie             Little Singham Future mein Satakli
# 857     s858  TV Show                                   The Neighbor
# 876     s877  TV Show                                   Alma Matters
# 965     s966  TV Show                                         Yasuke
#
#                          director  \
# 4250                          NaN
# 7790                  Frank Capra
# ...

# %%
filtered_df = df[((df['type'] == 'Movie') & (df['listed_in'] == 'Dramas')) | ((df['type'] == 'TV Show') & (df['listed_in'] == 'Kids TV'))]
filtered_df
# Out:
#      show_id   type                title             director  \
# 112     s113  Movie                Worth       Sara Colangelo
# 129     s130  Movie   An Unfinished Life      Lasse Hallström
# 142     s143  Movie      Freedom Writers  Richard LaGravenese
# 162     s163  Movie             Marshall      Reginald Hudlin
# 329     s330  Movie  Catch Me If You Can     Steven Spielberg
# ...      ...    ...                  ...                  ...
# 8674   s8675  Movie      Viceroy's House      Gurinder Chadha
# 8675   s8676  Movie               Victor    Brandon Dickerson
# 8685   s8686  Movie                  VS.             Ed Lilly
# 8691   s8692  Movie            Wakefield        Robin Swicord
# 8696   s8697  Movie            War Horse     Steven Spielberg
#
#                                                    cast  \
# 112   Michael Keaton, Stanley Tucci, Amy Ryan, Shuno...
# 129   Robert Redford, Jennifer Lopez, Morgan Freeman...
# ...
